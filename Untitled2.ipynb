# %%
import os 
import datetime
import datetime 
import numpy as np

# %%
start=datetime.datetime.now()
result = np.array([])
for i in range(100000):
    if i % 7 == 0: 
        result = np.append(result, i)
end=datetime.datetime.now()
print(end-start)
# Out:
# 0:00:00.183943

# %%
print(result)
# Out:
# [0.0000e+00 7.0000e+00 1.4000e+01 ... 9.9981e+04 9.9988e+04 9.9995e+04]

# %%
result.astype('int32')
# Out:
# array([    0,     7,    14, ..., 99981, 99988, 99995], dtype=int32)

# %%
for i in result: 
    print(i)
# Out:
# 0.0
# 7.0
# 14.0
# 21.0
# 28.0
# 35.0
# 42.0
# 49.0
# 56.0
# 63.0
# 70.0
# 77.0
# 84.0
# 91.0
# 98.0
# 105.0
# 112.0
# 119.0
# 126.0
# 133.0
# 140.0
# 147.0
# 154.0
# 161.0
# 168.0
# 175.0
# 182.0
# 189.0
# 196.0
# 203.0
# 210.0
# 217.0
# 224.0
# 231.0
# 238.0
# 245.0
# 252.0
# 259.0
# 266.0
# 273.0
# 280.0
# 287.0
# 294.0
# 301.0
# 308.0
# 315.0
# 322.0
# 329.0
# 336.0
# 343.0
# 350.0
# 357.0
# 364.0
# 371.0
# 378.0
# 385.0
# 392.0
# 399.0
# 406.0
# 413.0
# 420.0
# 427.0
# 434.0
# 441.0
# 448.0
# 455.0
# 462.0
# 469.0
# 476.0
# 483.0
# 490.0
# 497.0
# 504.0
# 511.0
# 518.0
# 525.0
# 532.0
# 539.0
# 546.0
# 553.0
# 560.0
# 567.0
# 574.0
# 581.0
# 588.0
# 595.0
# 602.0
# 609.0
# 616.0
# 623.0
# 630.0
# 637.0
# 644.0
# 651.0
# 658.0
# 665.0
# 672.0
# 679.0
# 686.0
# 693.0
# 700.0
# 707.0
# 714.0
# 721.0
# 728.0
# 735.0
# 742.0
# 749.0
# 756.0
# 763.0
# 770.0
# 777.0
# 784.0
# 791.0
# 798.0
# 805.0
# 812.0
# 819.0
# 826.0
# 833.0
# 840.0
# 847.0
# 854.0
# 861.0
# 868.0
# 875.0
# 882.0
# ...
